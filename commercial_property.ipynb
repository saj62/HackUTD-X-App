# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib as plt

df = pd.read_csv('datasets/crime_rates.csv')
df.head(10)
# Out:
#                   state  pop2020  reported      rate  violent  violentRate  \
# 0  District of Columbia   670868     14113  7985.932     7127      999.837
# 1            New Mexico  2118390     22077  6462.032    16393      778.277
# 2             Louisiana  4651664     35473  6408.216    29704      639.440
# 3              Colorado  5784865     30238  6090.756    24570      423.058
# 4        South Carolina  5131848     33133  5972.837    27691      530.678
# 5              Arkansas  3014195     25590  5898.753    20363      671.930
# 6              Oklahoma  3964912     23666  5869.825    18255      458.578
# 7            Washington  7724031     28061  5758.570    22596      293.698
# 8             Tennessee  6925619     51314  5658.304    46328      672.704
# 9                Oregon  4244795     17698  5609.893    12380      291.877
#
#    nonViolent  nonViolentRate
# 0       49798        6986.095
# 1      119718        5683.754
# 2      267978        5768.776
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64092 entries, 0 to 64091
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     64092 non-null  object
#  1   disaster_number             64092 non-null  int64
#  2   state                       64092 non-null  object
#  3   declaration_type            64092 non-null  object
#  4   declaration_date            64092 non-null  object
#  5   fy_declared                 64092 non-null  int64
#  6   incident_type               64092 non-null  object
#  7   declaration_title           64092 non-null  object
#  8   ih_program_declared         64092 non-null  int64
#  9   ia_program_declared         64092 non-null  int64
#  10  pa_program_declared         64092 non-null  int64
#  11  hm_program_declared         64092 non-null  int64
#  12  incident_begin_date         64092 non-null  object
# ...

# %%
plt.pyplot.figure(figsize=(24,12))
sns.barplot(x=df['state'], y=df['rate'])
# Out:
# <Axes: xlabel='state', ylabel='rate'>
